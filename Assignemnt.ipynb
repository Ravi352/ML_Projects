# %%
import openai
import sqlite3

# Configure your OpenAI API key
openai.api_key = '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'

# Connect to the SQLite database
conn = sqlite3.connect('Assign.db')
cursor = conn.cursor()

# Define a function to retrieve data from the database
def get_data_from_db():
    cursor.execute(f"""SELECT "NPS", "Seat Retainer Upstream", "Seat Retainer Downstream"
FROM "Torque Data"
WHERE Pressure BETWEEN 200 AND 250 AND NPS=4
ORDER BY "Seat Retainer Downstream" DESC
LIMIT 1; """, ('some_value',))
    result = cursor.fetchall()
    return result

# Define a function to interact with the chatbot
def chat_with_bot(input_text):
    # Prepare the conversation with the chatbot
    conversation = [
        {"role": "user", "content": input_text},
        {"role": "assistant", "content": "Generate a response based on user input and database data."}
    ]

    # Make an API call to GPT-3.5
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=conversation
    )

    # Extract and return the chatbot's reply
    chatbot_reply = response['choices'][0]['message']['content']
    return chatbot_reply

# Example usage
user_input = "Tell me something about the data from the database."
data_from_db = get_data_from_db()
chatbot_response = chat_with_bot(user_input)

# Print the chatbot's response
print(chatbot_response)

# %%
# !pip install openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 2.0 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# ...

# %%
import openai
import sqlite3

# Configure your OpenAI API key
openai.api_key = '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'

# Connect to the SQLite database
conn = sqlite3.connect('Assign7.db')
cursor = conn.cursor()

# Define a function to retrieve data from the database
def get_data_from_db():
    cursor.execute("""
    SELECT "NPS", "Seat Retainer Upstream", "Seat Retainer Downstream"
    FROM "Torque Data"
    WHERE Pressure BETWEEN 150 AND 200 AND NPS=4
    ORDER BY "Seat Retainer Downstream" DESC
    LIMIT 1; """)
    result = cursor.fetchall()
    return result

# Define a function to interact with the chatbot
def chat_with_bot(input_text):
    # Prepare the conversation with the chatbot
    conversation = [
        {"role": "user", "content": input_text},
        {"role": "assistant", "content": "Generate a response based on user input and database data."}
    ]

    # Make an API call to GPT-3.5
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=conversation
    )

    # Extract and return the chatbot's reply
    chatbot_reply = response['choices'][0]['message']['content']
    return chatbot_reply

# Example usage
user_input = f"Tell me the what will be the values Seat Retainer Upstream and Seat Retainer downstream at NSP of 2"
# You can set the NPS value dynamically

data_from_db = get_data_from_db()
chatbot_response = chat_with_bot(user_input)

# Print the chatbot's response
print(chatbot_response)
# Out:
# I apologize, but I'm unable to provide the specific values for Seat Retainer Upstream and Seat Retainer Downstream at NSP of 2.

# %%
import sqlite3
import openai

# Set your API key
api_key = "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"

# Initialize the OpenAI API client
openai.api_key = api_key

# Connect to the SQLite database
db_connection = sqlite3.connect('Assign7.db')
cursor = db_connection.cursor()

# Execute an SQL query
query = """SELECT * FROM "Torque Data" """
cursor.execute(query)

# Fetch the query result
result = cursor.fetchall()

# Close the database connection
db_connection.close()

# Format the data for ChatGPT
chat_messages = [
    {"role": "system", "content": "You are a database assistant. and please give the exact values of the given instruction on the basis on the above database"},
    {"role": "user", "content": "can you tell me the Seat Retainer Upstream and Seat Retainer downstream value at pressure 150 psi and 4 NPS"}
]

# Add the database result to the user's input
if result:
    chat_messages.append({"role": "assistant", "content": str(result)})
else:
    chat_messages.append({"role": "assistant", "content": "I couldn't find any data that matches your query."})

# Send the conversation to ChatGPT
response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=chat_messages,
)

# Extract and print the assistant's reply
assistant_reply = response['choices'][0]['message']['content']
print("Assistant:", assistant_reply)
# Out:
# Assistant: To find the Seat Retainer Upstream and Seat Retainer Downstream values at pressure 150 psi and 4 NPS, we need to filter the database for the matching pressure and NPS values:
#
# Seat Retainer Upstream at pressure 150 psi and 4 NPS: 4.0
# Seat Retainer Downstream at pressure 150 psi and 4 NPS: 275
